# %% [markdown]
# <a href="https://colab.research.google.com/github/DiwakarBasnet/Indigenous_language_translator/blob/main/translation_dataset_upload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets -q
# !apt install git-lfs -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 31.4 MB/s eta 0:00:00
# Reading package lists...
# Building dependency tree...
# Reading state information...
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.

# %%
# !git config --global user.email "basnet7diwakar@gmail.com"
# !git config --global user.name "DiwakarBasnet"

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
import csv
import json

# Open the CSV file in read mode
with open('newari_english_maithili.csv', 'r') as csv_file:
    # Create a CSV reader object
    csv_reader = csv.reader(csv_file)
    next(csv_reader)
    # Create an empty list to store the JSON objects
    json_list = []

    # Loop through each row in the CSV file
    for row in csv_reader:
        # Create a dictionary object for the row
        translation = {
            'new': str(row[0]),
            'en': str(row[1]),
            'mai': str(row[2])
        }
        # Add the dictionary object to the JSON list
        json_list.append(translation)

# %%
print(json_list)
# Out:
# [{'new': 'भ्वंया ख्वला।', 'en': 'paper cup.', 'mai': 'कागज के कप'}, {'new': 'ज्वजलपा तता !', 'en': 'hello sister ! namaskar.', 'mai': 'नमस्कार बहिन ! नमस्कार।'}, {'new': 'छन्हु गामय् तच्वकं खुसिबा: वल।', 'en': 'one day, there came a big flood.', 'mai': 'एक दिन, बड़का बाढ़ि आबि गेल।'}, {'new': 'जि ब्वनेकुथिं लिहां वयाः वसः हिलाबुला याये।', 'en': 'i change my dress after returning from the school.', 'mai': 'स्कूल स घुरलाक बाद हम अपन ड्रेस बदलि लैत छी।'}, {'new': 'वया बाः नं धयादिल, अज्या:पिं मनूतला यक्व दु।', 'en': 'his father said, there are several good people like that.', 'mai': 'ओकर पिता कहलनि, एहन कतेको नीक लोक छथि |'}, {'new': 'ध्वाँय्\u200cया च्वय्\u200cया स्वकुंमन्दलय् तिमिला दु।', 'en': 'there is a symbol of the moon in the upper triangle.', 'mai': 'ऊपरी त्रिकोण मे चन्द्रमाक प्रतीक अछि |'}, {'new': 'ब्वनेकुथि वा छेँय् दुगु थीथी ज्वलं गथे कि तेबुल, मेच, देस्क, सफू, कुतःसफू, च्वसा, थलबल थें ज्वगु ज्वलं क्यना: किपा च्वयेगु ह:पा: बियादिसँ।', 'en': 'let the students observe objects
# ...

# %%
import pandas as pd

# Create sample data with dictionaries
data = {
    'translation': json_list
}

# Create a DataFrame from the data
df = pd.DataFrame(data)
df = df.reset_index(drop=True)
# Display the DataFrame
print(df)
# Out:
#                                             translation
# 0     {'new': 'भ्वंया ख्वला।', 'en': 'paper cup.', '...
# 1     {'new': 'ज्वजलपा तता !', 'en': 'hello sister !...
# 2     {'new': 'छन्हु गामय् तच्वकं खुसिबा: वल।', 'en'...
# 3     {'new': 'जि ब्वनेकुथिं लिहां वयाः वसः हिलाबुला...
# 4     {'new': 'वया बाः नं धयादिल, अज्या:पिं मनूतला य...
# ...                                                 ...
# 2489  {'new': 'मामं धाकाया लं फिनादिइ।', 'en': 'her ...
# 2490  {'new': 'बुदनि ल्वय् लंका: ब्वनेकुथिइ वनाच्वन।...
# 2491  {'new': 'छित: गज्या:गु वस: पुने य: ?', 'en': '...
# 2492  {'new': 'व च्वनिइगु सहर तराइ पाखे ला:।', 'en':...
# 2493  {'new': 'ब्वनेज्याय् बियात:गु याज्या बांलाक या...
#
# [2494 rows x 1 columns]

# %%
from datasets import Dataset

new_eng_mai_trans = Dataset.from_pandas(df)

# %%
new_eng_mai_trans['translation'][0]
# Out:
# {'en': 'paper cup.', 'mai': 'कागज के कप', 'new': 'भ्वंया ख्वला।'}

# %%
new_eng_mai_trans.push_to_hub("new-eng-mai")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/3 [00:00<?, ?ba/s]
